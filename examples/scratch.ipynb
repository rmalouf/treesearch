# %%
import treesearch

# %%
input = """# sent_id = 1
# text = The big dog runs in the park.
# source = test
1	The	the	DET	DT	_	3	det	_	_
2	big	big	ADJ	JJ	_	3	amod	_	_
3	dog	dog	NOUN	NN	_	4	nsubj	_	_
4	runs	run	VERB	VBZ	_	0	root	_	_
5	in	in	ADP	IN	_	7	case	_	_
6	the	the	DET	DT	_	7	det	_	_
7	park	park	NOUN	NN	_	4	obl	_	_
x	.	.	PUNCT	.	_	4	punct	_	_

"""

# %%
tb = treesearch.from_string(input)

# %%
trees = list(tb.trees())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 trees = list(tb.trees())
#
# ValueError: Parse error: Parse error at line 11: Invalid token ID: x
#   Line: x	.	.	PUNCT	.	_	4	punct	_	_

# %%
trees[0]
# Out:
# <Tree len=8 words='The big dog ...'>

# %%
trees[0][3]
# Out:
# <Word id=3 form='runs' lemma='run' upos='VERB' deprel='root'>

# %%
trees[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 trees[-10]
#
# IndexError: list index out of range

# %%
(i for i in range(5))
# Out:
# <generator object <genexpr> at 0x10bd213c0>
